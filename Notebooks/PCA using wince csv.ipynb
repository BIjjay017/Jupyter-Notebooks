# %%
import pandas as pd
import numpy as np
import sklearn

import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
wine = pd.read_csv("wine.csv")

# %%
wine
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# ...

# %%
for c in wine.columns[1:]:
    wine.boxplot(c,by = "Wine",figsize=(7,4),fontsize=14)
    plt.title("{}\n".format(c),fontsize=16)
    plt.xlabel("Wine Class",fontsize=16)

# %%
plt.figure(figsize=(10,6))
plt.scatter(wine['Phenols'],wine['Flavanoids'],c=wine['Wine'],edgecolors='k',alpha=0.75,s=150)
plt.grid(True)

# %%
#Data Scaling

# %%
from sklearn .preprocessing import StandardScaler

# %%
scale= StandardScaler()

# %%
x=wine.drop('Wine',axis=1)
y=wine['Wine']

# %%
x=scaler.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 x=scaler.fit_transform(x)
#
# NameError: name 'scaler' is not defined

# %%
dfx=pd.DataFrame(data=x,columns=wine.columns[1:])

# %%
dfx.head()
# Out:
#    Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
dfx_pca.explained_variance_
# Out:
# array([9.92017895e+04, 1.72535266e+02, 9.43811370e+00, 4.99117861e+00,
#        1.22884523e+00, 8.41063869e-01, 2.78973523e-01, 1.51381266e-01,
#        1.12096765e-01, 7.17026032e-02, 3.75759789e-02, 2.10723661e-02,
#        8.20370314e-03])

# %%
dfx_pca=pca.fit(dfx)

# %%
dfx_trans = pca.transform(dfx)

# %%
dfx_trans = pd.DataFrame(data=dfx_trans)

# %%
dfx_trans.head(10)
# Out:
#             0          1
# 0  318.562979  21.492131
# 1  303.097420  -5.364718
# 2  438.061133  -6.537309
# 3  733.240139   0.192729
# 4  -11.571428  18.489995
# 5  703.231192  -0.332159
# 6  542.971581 -13.518967
# 7  548.401860  11.449432
# 8  298.036863  -8.180158
# 9  298.049553  -7.101543

# %%
plt.figure(figsize=(10,6))
plt.scatter(dfx_trans[0],dfx_trans[1],c=wine['Wine'],edgecolors='k',alpha=0.75,s=150)
plt.grid(True)
